# %% [markdown]
# ### Explanation of the Code
# Define Cluster Centers: The cluster_centers array defines RGB points representing clusters: red, green, blue, and yellow.
#
# Generate Random Data for Each Cluster:
#
# The np.random.normal function generates points around each center with a spread (standard deviation) of 0.2.
# The number of points per cluster is defined by n_samples.
# Normalize Data:
#
# After all clusters are generated, they are normalized to fall between 0 and 1.
# Save Data to CSV:
#
# The normalized data is saved as test_data.csv, with columns X, Y, and Z.
# 3D Plot of the Data:
#
# The data is visualized in a 3D scatter plot, with color representing the normalized RGB values.

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Wed Dec  6 18:57:06 2023
Updated for SSOM test data generation and visualization

Generates a synthetic dataset for testing a Self-Organizing Map (SSOM),
saving the data to a CSV file and visualizing it in a 3D plot.
"""

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Fixing random state for reproducibility
np.random.seed(19680801)

# Define the number of samples per cluster
n_samples = [2000, 500, 500, 500]

# Define the cluster centers in RGB space
cluster_centers = np.array([
    [0.99, 0.0, 0.0],   # Red
    [0.0, 0.95, 0.0],   # Green
    [0.0, 0.0, 0.95],   # Blue
    [1.0, 1.0, 0.0]     # Yellow
])

# Generate data with clusters around each defined center
data = []
for i, center in enumerate(cluster_centers):
    samples = np.random.normal(loc=center, scale=0.2, size=(n_samples[i], 3))
    data.append(samples)

# Concatenate all clusters into a single dataset
data = np.vstack(data)

# Normalize data to be between 0 and 1
data_normalized = (data - np.min(data)) / (np.max(data) - np.min(data))

# Save the generated data to a CSV file
pd.DataFrame(data_normalized, columns=["X", "Y", "Z"]).to_csv('test_data.csv', index=False)
print("Generated data saved to 'test_data.csv'")

# Plot the data in 3D space
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(data_normalized[:, 0], data_normalized[:, 1], data_normalized[:, 2], c=data_normalized, marker='o')
ax.view_init(elev=10, azim=30)

# Set labels for axes
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
plt.title("3D Scatter Plot of Generated SSOM Test Data")
plt.show()
# Out:
# Generated data saved to 'test_data.csv'

# %%
import pandas as pd
from ssom import SSOM
# Load the generated test data
data = pd.read_csv('test_data.csv').values

# Assuming SSOM is defined and imported correctly
som = SSOM(grid_size=(10, 10), num_iterations=5000, grid_shape="2D")
som.train(data)
# Out:
# SSOM Initial Settings:
#   Grid Shape: 2D
#   Grid Size: 10x10
#   Number of Iterations: 5000
#   Max Learning Rate: 0.1
#   Learning Decay: 0.25
#   Neighborhood Decay: 0.5
#   Metric: euclidean
#   Log Interval: 50
#
# Initialized SOM grid with random weights.
# Iter 5000/5000 [==================================================]  LearnRate: 0.0018

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_som_grid_as_colormap(som):
    """
    Plot each historical SOM grid state as a 2D color map, representing 3D (RGB) nodes.
    
    Parameters:
    - som: Trained SSOM instance with `som_grid_history` containing 3-dimensional (RGB) nodes.
    """
    # Ensure the SOM is 2D with RGB nodes
    assert som.grid_shape == "2D" and som.som_grid_history[0].shape[-1] == 3, "SOM must be 2D with RGB nodes."

    # Loop through each historical grid state
    for i, som_grid in enumerate(som.som_grid_history):
        # Normalize the grid values to be between 0 and 1 for valid RGB colors
        normalized_grid = (som_grid - som_grid.min()) / (som_grid.max() - som_grid.min())

        # Reshape grid to (rows, cols, 3) format for plotting
        rgb_image = normalized_grid

        # Plot the color map
        plt.figure(figsize=(6, 6))
        plt.imshow(rgb_image)
        plt.axis('off')
        plt.title(f"SOM Grid - Iteration Step {som.step_history[i]}")
        plt.show()

# Assuming `som` is a trained SSOM instance
plot_som_grid_as_colormap(som)
